# %%
#!pip install google-api-python-client

id1=[]

# %%
from googleapiclient.discovery import build

# %%
youTubeApiKey='AIzaSyDHE1DPWjxxjWjvRRQi8xGN1fN9DAIfZtg'
youtube=build('youtube','v3',developerKey=youTubeApiKey)
channelId='UCr2dD3s19bdcw4qjuUTQKiQ'

# %%
# create a list id1 
id1=[]

# %%
#Final Code for Random Channel ID retreival

import json
import urllib.request
import string
import random

count = 50
API_KEY = 'AIzaSyC5MWRF6_O-qhuEMLtgPGntlWLowAnWbf4'
random = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(3))

urlData = "https://www.googleapis.com/youtube/v3/search?key={}&maxResults={}&part=snippet&type=video&q={}".format(API_KEY,count,random)
webURL = urllib.request.urlopen(urlData)
data = webURL.read()
encoding = webURL.info().get_content_charset('utf-8')
results = json.loads(data.decode(encoding))

for data in results['items']:
    videoId = (data['id']['videoId'])
    channelId=(data['snippet']['channelId'])
    id1.append((videoId,channelId))

# %%
#separate the channel id and append to a new list , then create it as a dataframe
import pandas as pd
idchannel=[]
for i in range(0,len(id1)):
    idchannel.append(id1[i][1])

# %%
#idchannel=pd.DataFrame(idchannel)
idchannel[249]
videos=[]

# %%
#Get information about each video channel
#create a list to save data about video

for i in range(0,250):
    contentdata=youtube.channels().list(id=idchannel[i],part='contentDetails').execute()
    playlist_id = contentdata['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    next_page_token = None



    while 1:
         res = youtube.playlistItems().list(playlistId=playlist_id,part='snippet',maxResults=5,pageToken=next_page_token).execute()
         videos += res['items']
         break

# %%
len(videos)
# Out:
# 1200

# %%
len(idchannel)
# Out:
# 250

# %%
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], videos))
len(video_ids)
# Out:
# 1200

# %%
stats = []
for i in range(0, len(video_ids), 40):
    res = (youtube).videos().list(id=','.join(video_ids[i:i+40]),part='statistics').execute()
    stats += res['items']

stats

# %%
videos[0]
# Out:
# {'kind': 'youtube#playlistItem',
#  'etag': 'uNQ8DprZy57XQK-cZHzsX7z0RO4',
#  'id': 'VVV4alM2MHhSVjhxNFFiU19IT3VuVVdnLlc3LVlsQV9hY3lz',
#  'snippet': {'publishedAt': '2019-09-18T16:19:13Z',
#   'channelId': 'UCxjS60xRV8q4QbS_HOunUWg',
#   'title': 'CHIMERE- 7UA × MXRGH3',
#   'description': 'Brano di genere rap/trap\ninstagram: zuaa_ch .  x.mxrgh3\nBuon ascolto.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/W7-YlA_acys/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/W7-YlA_acys/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/W7-YlA_acys/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/W7-YlA_acys/sddefault.jpg',
#     'width': 640,
#     'height': 480}},
#   'channelTitle': '7UA',
#   'playlistId': 'UUxjS60xRV8q4QbS_HOunUWg',
#   'position': 0,
# ...

# %%
print((videos[0])['snippet']['title'])
print("https://www.youtube.com/watch?v="+(videos[0])['snippet']['resourceId']['videoId'])
print(int((stats[0])['statistics']['likeCount']))
print(int((stats[0])['statistics']['dislikeCount']))
print(int((stats[0])['statistics']['viewCount']))
print(int((stats[50])['statistics']['commentCount']))
print((videos[0])['snippet']['publishedAt'])
# Out:
# CHIMERE- 7UA × MXRGH3
# https://www.youtube.com/watch?v=W7-YlA_acys
# 31
# 3
# 739
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-130-0d63a145499e> in <module>
#       4 print(int((stats[0])['statistics']['dislikeCount']))
#       5 print(int((stats[0])['statistics']['viewCount']))
# ----> 6 print(int((stats[50])['statistics']['commentCount']))
#       7 print((videos[0])['snippet']['publishedAt'])
#
# KeyError: 'commentCount'

# %%
if 'commentCount' in (stats[50])['statistics'] :
    print('hi')
else:
    print('bye')
# Out:
# bye

# %%
title=[ ]
liked=[ ]
disliked=[ ]
views=[ ]
url=[ ]
comment=[ ]
published=[]


for i in range(len(videos)):
    title.append((videos[i])['snippet']['title'])
    url.append("https://www.youtube.com/watch?v="+(videos[i])['snippet']['resourceId']['videoId'])
    if 'likeCount' in (stats[i])['statistics'] :
        liked.append(int((stats[i])['statistics']['likeCount']))
    else:
        liked.append(0)
    if 'dislikeCount' in (stats[i])['statistics'] :
        disliked.append(int((stats[i])['statistics']['dislikeCount']))
    else:
        disliked.append(0)
    if 'viewCount' in (stats[i])['statistics'] :
        views.append(int((stats[i])['statistics']['viewCount']))
    else:
        views.append(0)
    if 'commentCount' in (stats[i])['statistics'] :
        comment.append(int((stats[i])['statistics']['commentCount']))
    else:
        comment.append(0)
    published.append((videos[i])['snippet']['publishedAt'])
data={'title':title,'url':url,'liked':liked,'disliked':disliked,'views':views,'comment':comment}
df=pd.DataFrame(data)
# Out:
# (1200, 6)

# %%
len(published)
# Out:
# 50

# %%
df.to_csv('youtube_scraping.csv',index=False)

# %%
final=pd.merge(df,pd.DataFrame(published),how='inner',left_index=True,right_index=True).fillna(0)

# %%
final.to_csv('Final.csv',index=False)

# %%
statdata=youtube.channels().list(part='statistics',id=channelId).execute()
stats=statdata['items'][0]['statistics']
statdata
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '4aehd7HYBRLzjVMWXf-JPxstZaQ',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '4BbGrpjXDYAwVeekRXD3UK5Fud4',
#    'id': 'UCr2dD3s19bdcw4qjuUTQKiQ',
#    'statistics': {'viewCount': '18642',
#     'commentCount': '0',
#     'subscriberCount': '0',
#     'hiddenSubscriberCount': True,
#     'videoCount': '236'}}]}

# %%
snippetdata=youtube.channels().list(part='snippet',id=channelId).execute()
snippetdata
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '54DFtjHxU51iiGmkXSM8GAlAEtg',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '5ZYIiJhLUSwIko-4qUmRxCeUbPE',
#    'id': 'UCr2dD3s19bdcw4qjuUTQKiQ',
#    'snippet': {'title': 'Rajni Sharma Maths Classes',
# ...

# %%
title=snippetdata['items'][0]['snippet']['title']

description=snippetdata['items'][0]['snippet']['description']
description
logo=snippetdata['items'][0]['snippet']['publishedAt']
logo
# Out:
# '2019-06-26T02:36:45Z'

# %%
contentdata=youtube.channels().list(id=channelId,part='contentDetails').execute()
playlist_id = contentdata['items'][0]['contentDetails']['relatedPlaylists']['uploads']
videos = [ ]
next_page_token = None



while 1:
     res = youtube.playlistItems().list(playlistId=playlist_id,part='snippet',maxResults=50,pageToken=next_page_token).execute()
     videos += res['items']
     next_page_token = res.get('nextPageToken')



     if next_page_token is None:
        break
print(videos)
# Out:
# [{'kind': 'youtube#playlistItem', 'etag': 'X3Fq22kjAFwCQEcRXaVdTsViHXY', 'id': 'VVVyMmREM3MxOWJkY3c0cWp1VVRRS2lRLktua0tHZEJnSlJJ', 'snippet': {'publishedAt': '2020-06-03T14:14:13Z', 'channelId': 'UCr2dD3s19bdcw4qjuUTQKiQ', 'title': 'Arithmetic Progression | Chapter 5 Ex 5.2 Q 19 | NCERT | Maths Class 10th', 'description': "In this video we have discussed step by step solution of Class 10th Question 19 of Exercise 5.2 Arithmetic Progression.\n\nFor previous videos you can check our Channel's playlist and subscribe our channel.\n\nWe are uploading one video daily for Completing the Syllabus of Class 10 before final examinations.\n\nClass 10th Maths\nClass 10th Maths Chapter 5 Solutions\nClass 10th Maths Ex 5.2 q 19", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KnkKGdBgJRI/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/KnkKGdBgJRI/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/KnkKGdBgJRI/hqdefaul
# ...

# %%
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], videos))
video_ids
# Out:
# ['KnkKGdBgJRI',
#  'RearjNzhdFc',
#  'sir2HFUWGZ0',
#  'Gr8FqExvFLE',
#  'hvuaWgF2xOQ',
#  'Vp9b-6nO3MU',
#  'KrgTWOoqKW4',
#  'olTMlhaG2Us',
#  'Ion-IMRNtbw',
#  'BMzw5Tzfu1k',
#  'VXAuiJjg_i4',
#  'zJmUKyF4nS4',
#  'JL_fxSsNwbU',
#  'q-y5ZyI0tdA',
#  '1mhXd2fC5Ig',
#  'zNfed9VZ3xM',
#  '45_hqVdHAps',
#  'w7bIrdlbG_o',
#  'hYNEG-FX4C8',
#  'TpjPmvqSbz0',
#  'l8ScRO4cQI4',
#  'GCxxtlGSdSo',
#  'zOIZzq0Zo60',
#  'udPVjKlCpp4',
#  '-2Ty-XTT6pM',
#  'GkW2KlfV0-8',
#  '9TmhLtHUROo',
#  '2VViJgBztTw',
#  'yMj1BjKuHdE',
#  'utJ0AzluChY',
#  'K_jA9iPZSFc',
#  'X15Sd3xG8QY',
#  'em4KOt0Bfgk',
#  'YFiouoh_jxc',
#  '1osMEaHX0oM',
#  'cfx-9R1lr7o',
#  '3CFJu_7iTYc',
#  'NFiaXqc1dgc',
#  'crvwUQsI4Vs',
#  'vVOnWeu_Ifg',
#  'KhX1PKCs23A',
#  'o61nJmIydjk',
#  'TVtZ5NDbmMQ',
#  'Osuf3WzFiew',
#  'MJ92yAMyC1s',
#  'C4koMKM610s',
#  'sGEJgmuEASU',
#  'fELKTjwCMNE',
#  '_dfZgJn5dT0',
#  '0MOySpitvfQ',
#  'Q8BtkSywzPM',
#  'ad9LXq-NVo8',
#  'pqsIisBd9ww',
#  'Q4vM3pCgSA8',
#  '03pwuLROPm0',
# ...

# %%
stats = []
for i in range(0, len(video_ids), 40):
    res = (youtube).videos().list(id=','.join(video_ids[i:i+40]),part='statistics').execute()
    stats += res['items']
print(stats)
# Out:
# [{'kind': 'youtube#video', 'etag': '4yQXXCcCB1sYU_UVUz2eQR2sHqs', 'id': 'KnkKGdBgJRI', 'statistics': {'viewCount': '39', 'likeCount': '4', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '1'}}, {'kind': 'youtube#video', 'etag': 'UpWMmEMOQrJt9Fe_MfdRx75Xv2g', 'id': 'RearjNzhdFc', 'statistics': {'viewCount': '13', 'likeCount': '2', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '0'}}, {'kind': 'youtube#video', 'etag': 'NDiLaRrIEb_5755lakVhJwEw8Hc', 'id': 'sir2HFUWGZ0', 'statistics': {'viewCount': '17', 'likeCount': '3', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '1'}}, {'kind': 'youtube#video', 'etag': 'q0inyK0l-yn8wBac4YaIm-2V3p4', 'id': 'Gr8FqExvFLE', 'statistics': {'viewCount': '8', 'likeCount': '2', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '0'}}, {'kind': 'youtube#video', 'etag': 's0Xl5EY05g43hta_j2CclRxQtF4', 'id': 'hvuaWgF2xOQ', 'statistics': {'viewCount': '6', 'likeCount': '3', 'dislikeCount': '0', 'favoriteCount': '0', 'c
# ...

# %%
title=[ ]
liked=[ ]
disliked=[ ]
views=[ ]
url=[ ]
comment=[ ]

for i in range(len(videos)):
    
      title.append((videos[i])['snippet']['title'])
      url.append("https://www.youtube.com/watch?v="+(videos[i])['snippet']['resourceId']['videoId'])
      liked.append(int((stats[i])['statistics']['likeCount']))
      disliked.append(int((stats[i])['statistics']['dislikeCount']))
      views.append(int((stats[i])['statistics']['viewCount']))
      comment.append(int((stats[i])['statistics']['commentCount']))
data={'title':title,'url':url,'liked':liked,'disliked':disliked,'views':views,'comment':comment}
df=pd.DataFrame(data)
df

# %%
import pandas as pd
data={'title':title,'url':url,'liked':liked,'disliked':disliked,'views':views,'comment':comment}
df=pd.DataFrame(data)
df
# Out:
#                                                  title  \
# 0    Arithmetic Progression | Chapter 5 Ex 5.2 Q 19...
# 1    Arithmetic Progression | Chapter 5 Ex 5.2 Q 18...
# 2    Arithmetic Progression | Chapter 5 Ex 5.2 Q 17...
# 3    Arithmetic Progression | Chapter 5 Ex 5.2 Q 16...
# 4    Arithmetic Progression | Chapter 5 Ex 5.2 Q 15...
# ..                                                 ...
# 231  Class 10th Exercise 1.1 | Question 3 | Real Nu...
# 232  Class 10th Exercise 1.1 | Question 2 | Real Nu...
# 233  Class 10th | Exercise 1. 1 | Question 1 | Real...
# 234  Euclid's Division Lemma Class 10 | Maths Chapt...
# 235  Real Numbers Chapter 1 Ex 1.1 Intro NCERT Clas...
#
#                                              url  liked  disliked  views  \
# 0    https://www.youtube.com/watch?v=KnkKGdBgJRI      4         0     39
# 1    https://www.youtube.com/watch?v=RearjNzhdFc      2         0     13
# 2    https://www.youtube.com/watch?v=sir2HFUWGZ0      3         0     17
# ...

# %%
from apiclient.discovery import build
from apiclient.errors import HttpError
from oauth2client.tools import argparser

# Set DEVELOPER_KEY to the API key value from the APIs & auth > Registered apps
# tab of
#   https://cloud.google.com/console
# Please ensure that you have enabled the YouTube Data API for your project.
DEVELOPER_KEY = 'AIzaSyC5MWRF6_O-qhuEMLtgPGntlWLowAnWbf4'
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"


def youtube_search(vid):
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
                    developerKey=DEVELOPER_KEY)

    # Call the search.list method to retrieve results matching the specified
    # query term.
    search_response = youtube.search().list(
    part="snippet",
    relatedToVideoId=vid,
    type="video",
).execute()
    return (search_response)


videos=[]

try:
    for i in id1:
        videos.append(youtube_search(i))
except HttpError as  e:
    print("An HTTP error %d occurred:\n%s" % (e.resp.status, e.content))

# %%
len(videos)
# Out:
# 83

# %%
stats1 = []
for i in range(0, len(id1),40):
    res = (youtube).videos().list(id=','.join(video_ids[i:i+40]),part='statistics').execute()
    stats1 += res['items']
print(stats)

# %%
from apiclient.discovery import build
from apiclient.errors import HttpError
from oauth2client.tools import argparser

# Set DEVELOPER_KEY to the API key value from the APIs & auth > Registered apps
# tab of
#   https://cloud.google.com/console
# Please ensure that you have enabled the YouTube Data API for your project.
DEVELOPER_KEY = 'AIzaSyDHE1DPWjxxjWjvRRQi8xGN1fN9DAIfZtg'
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"


def youtube_search(vid):
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
                    developerKey=DEVELOPER_KEY)

    # Call the search.list method to retrieve results matching the specified
    # query term.
    search_response = youtube.search().list(
    part="snippet",
    relatedToVideoId=vid,
    type="video",
).execute()
    return (search_response)



try:
    print(youtube_search("i0X-b07ob90"))
except HttpError as  e:
    print("An HTTP error %d occurred:\n%s" % (e.resp.status, e.content))
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': 'V2WKbDILwikSxkrT_b97q7KU_HU', 'nextPageToken': 'CAUQAA', 'regionCode': 'IN', 'pageInfo': {'totalResults': 47, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#searchResult', 'etag': 'a6oxRw1k1vahVzQCRfIs9AiS2PY', 'id': {'kind': 'youtube#video', 'videoId': '2ro6eC3gAHY'}, 'snippet': {'publishedAt': '2020-01-07T14:11:42Z', 'channelId': 'UCLzKhsxrExAC6yAdtZ-BOWw', 'title': 'HIGHLIGHTS: Juventus vs Cagliari - 4-0 - Ronaldo hat-trick!', 'description': 'What a start to 2020! Juventus were rampant in our first match of the new decade, putting 4 goals past Cagliari. Gonzalo Higuain provided one goal coming off the bench while Cristiano Ronaldo scored his first Serie A hat-trick!\n\n🎥 Follow our season with exclusive content only on Juventus TV ➡️ http://juve.it/av4M30lm55Y\n\n📹 Subscribe here to our YouTube channel: http://juve.it/BgUp30iwWec\n\n👕 Visit the Juventus Online Store for your very own shirt and other Bianconeri gifts: http://juve.i
# ...

# %%
#!pip install oauth2client

# %%
len(id1)
id100=id1[:101]
id200=id1[101:201]
id300=id1[201:301]
id400=id1[301:401]
id500=id1[401:499]

# %%
print(len(id500))
#id5=id1[:5]

id_csv=pd.DataFrame(id1)
# Out:
# 98

# %%
id_csv.to_csv('ids.csv',index=False)

# %%
#scrap from given url first 5 pages.we are using fake agent so that request looks like it comes from a user not computer
import requests
from bs4 import BeautifulSoup as bs
base_url="https://www.youtube.com/watch?v=SCAWNFbuLNA"
from fake_useragent import UserAgent
ua = UserAgent()
headers = {'user-agent':ua.chrome}
from tqdm import tqdm
import pandas as pd

# %%
id1[0]
# Out:
# 'SCAWNFbuLNA'

# %%
quote=[]
authors=[]
tags=[]
for i in id1[0:1]:
    url=base_url.format(i)
    markup=requests.get(url,headers=headers).text
    markup_parsed=BeautifulSoup(markup,'html.parser')
    #print(markup_parsed.find_all("script"))
    print(type(markup_parsed.find_all("script")[32]))
# Out:
# <class 'bs4.element.Tag'>

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.parse import urljoin

# URL of the web page you want to extract
url = "https://www.youtube.com/watch?v=SCAWNFbuLNA"

# initialize a session
session = requests.Session()
# set the User-agent as a regular browser
session.headers["User-Agent"] = "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"

# get the HTML content
html = session.get(url).content

# parse HTML using beautiful soup
soup = bs(html, "html.parser")

# get the JavaScript files
script_files = []

for script in soup.find_all("script"):
    if script.attrs.get("src"):
        # if the tag has the attribute 'src'
        script_url = urljoin(url, script.attrs.get("src"))
        script_files.append(script_url)

script_files
# Out:
# ['https://www.youtube.com/yts/jsbin/scheduler-vflpDL9Kn/scheduler.js',
#  'https://www.youtube.com/s/player/c718385a/player_ias.vflset/en_GB/base.js',
#  'https://www.youtube.com/yts/jsbin/spf-vflWelCdO/spf.js',
#  'https://www.youtube.com/yts/jsbin/network-vflJMU599/network.js',
#  'https://www.youtube.com/yts/jsbin/web-animations-next-lite.min-vflKXbQMP/web-animations-next-lite.min.js',
#  'https://www.youtube.com/yts/jsbin/webcomponents-lite-noPatch-vfl8wOTOU/webcomponents-lite-noPatch.js',
#  'https://www.youtube.com/yts/jsbin/www-i18n-constants-en_GB-vfl0iot7B/www-i18n-constants.js']

# %%
#!pip install requests_html
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-cp37-none-any.whl size=1278 sha256=6c205911c3e87fd936a8d012012cec118997e2452511b7c9a71ff1851e19e7c4
#   Stored in directory: C:\Users\Belle\AppData\Local\pip\Cache\wheels\a0\b0\b2\4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# ...
#   Created wheel for parse: filename=parse-1.16.0-cp37-none-any.whl size=24001 sha256=6c41f4a9c299b505ec6d10895f338567dc3176c5bfb3a63418728796d9f00e4a
#   Stored in directory: C:\Users\Belle\AppData\Local\pip\Cache\wheels\46\ca\7d\4e6d687c81f1110b47140845d6dce4e6d7cdae0996caeca560
# Successfully built bs4 parse
# ...
#   Found existing installation: urllib3 1.24.2
#     Uninstalling urllib3-1.24.2:
#       Successfully uninstalled urllib3-1.24.2
# ...

# %%
import json
from urllib.request import urlopen
oururl= urlopen('https://www.youtube.com/watch?v=SCAWNFbuLNA').read()
soup = BeautifulSoup(oururl)

data =json_loads(soup.find_all('script', type='application/ld+json').text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-157-448ba60fe830> in <module>
#       4 soup = BeautifulSoup(oururl)
#       5
# ----> 6 data =json_loads(soup.find_all('script', type='application/ld+json').text)
#
# NameError: name 'json_loads' is not defined

# %%
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.youtube.com/watch?v=SCAWNFbuLNA")

nav = browser.find_element_by_id("mainnav")

print(nav.text)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-159-ee77864a9a56> in <module>
#       5 browser.get("https://www.youtube.com/watch?v=SCAWNFbuLNA")
#       6
# ----> 7 nav = browser.find_element_by_id("mainnav")
#       8
#       9 print(nav.text)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_id(self, id_)
#     358             element = driver.find_element_by_id('foo')
#     359         """
# --> 360         return self.find_element(by=By.ID, value=id_)
#     361
#     362     def find_elements_by_id(self, id_):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
# ...
